# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib as mpl
mpl.rcParams['figure.facecolor'] = 'white'

# Specify years and terms
myharvard_year = "2025"
myharvard_term = "Fall"
qguide_year = "2024"
qguide_term = "Fall"

# Get the repository root directory
repo_root = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..', '..'))
folder_name = f"{myharvard_year}_{myharvard_term}_{qguide_year}_{qguide_term}"
input_file = os.path.join(repo_root, "release", "hugems", folder_name,"qguide_myharvard.csv")

pd.options.display.max_columns = None
df = pd.read_csv(input_file)
df.describe()
# Out:
#            course_id  num_responded  num_students  course_score_mean  \
# count     970.000000     970.000000    970.000000         970.000000
# mean   142104.485567      30.755670     38.432990           4.268722
# std     41334.734478      56.259489     70.111382           0.537997
# min       185.000000       5.000000      5.000000           1.670000
# 25%    113940.750000       8.000000     11.000000           3.965000
# 50%    122599.000000      13.000000     15.500000           4.370000
# 75%    153042.000000      28.000000     38.000000           4.680000
# max    225033.000000     600.000000    735.000000           5.000000
#
#        course_score_median  course_score_mode  course_score_stdev  \
# count           970.000000         970.000000          970.000000
# mean              4.443299           4.530928            0.715454
# std               0.664119           0.716582            0.341174
# min               1.000000           1.000000            0.000000
# 25%               4.000000           4.000000            0.487101
# 50%               5.000000           5.000000            0.756387
# 75%               5.000000           5.000000            0.943599
# max               5.000000           5.000000            1.608061
#
#        lecturer_score_mean  lecturer_score_median  lecturer_score_mode  \
# count           970.000000             970.000000           970.000000
# mean              4.020866               4.193299             4.221649
# std               1.540816               1.615044             1.646633
# min               0.000000               0.000000             0.000000
# 25%               4.100000               4.000000             5.000000
# 50%               4.630000               5.000000             5.000000
# 75%               4.890000               5.000000             5.000000
# max               5.000000               5.000000             5.000000
#
#        lecturer_score_stdev  workload_score_mean  workload_score_median  \
# count            970.000000           970.000000             970.000000
# mean               0.361061             7.024041               6.313402
# std                0.623262             3.183600               3.109164
# min               -1.000000             0.000000               0.000000
# 25%                0.000000             4.690000               4.000000
# 50%                0.443520             6.330000               5.000000
# 75%                0.802833             9.200000               8.500000
# max                1.742053            20.080000              20.000000
#
#        workload_score_mode  workload_score_stdev  rec_score_mean  \
# count           970.000000            970.000000      970.000000
# mean              7.137113              3.390495        4.245959
# std               4.748012              1.751554        0.521485
# min               0.000000             -1.000000        1.800000
# 25%               4.000000              2.250000        3.900000
# 50%               6.000000              3.180000        4.310000
# 75%              10.000000              4.450000        4.670000
# max              30.000000             13.620000        5.000000
#
#        rec_score_median  rec_score_mode  rec_score_stdev  \
# count        970.000000      970.000000       970.000000
# mean           4.430412        4.474227         0.748546
# std            0.609990        0.725374         0.369661
# min            2.000000        1.000000        -1.000000
# 25%            4.000000        4.000000         0.520000
# 50%            4.500000        5.000000         0.790000
# 75%            5.000000        5.000000         1.000000
# max            5.000000        5.000000         1.860000
#
#        sentiment_score_mean  sentiment_score_median  sentiment_score_mode  \
# count            970.000000              970.000000            970.000000
# mean               0.639083                0.732379              0.576751
# std                0.240137                0.257005              0.438191
# min               -0.386500               -0.386500             -0.969300
# 25%                0.504873                0.617637              0.007100
# 50%                0.687667                0.824200              0.794600
# 75%                0.822868                0.917738              0.944875
# max                0.998400                0.998400              0.998700
#
#        sentiment_score_stdev  gem_probability_mean  gem_probability_median  \
# count             970.000000            970.000000                   970.0
# mean                0.255663              0.006317                     0.0
# std                 0.351625              0.032758                     0.0
# min                -1.000000              0.000000                     0.0
# 25%                 0.143042              0.000000                     0.0
# 50%                 0.327300              0.000000                     0.0
# 75%                 0.445816              0.000000                     0.0
# max                 1.090854              0.333333                     0.0
#
#        gem_probability_mode  gem_probability_stdev  max_sent_score  \
# count                 970.0             970.000000      970.000000
# mean                    0.0              -0.035855        0.906573
# std                     0.0               0.242226        0.210378
# min                     0.0              -1.000000        0.000000
# 25%                     0.0               0.000000        0.930500
# 50%                     0.0               0.000000        0.977600
# 75%                     0.0               0.000000        0.991675
# max                     0.0               0.577350        0.999600
#
#        min_sent_score  max_gem_probability  class_number  waitlist  \
# count      970.000000           970.000000    970.000000     970.0
# mean        -0.209083             0.052432  13456.648454       0.0
# std          0.304249             0.213241   1700.151857       0.0
# min         -0.994400             0.000000  10521.000000       0.0
# 25%         -0.426050             0.000000  12554.500000       0.0
# 50%          0.000000             0.000000  13167.500000       0.0
# 75%          0.000000             0.000000  14111.750000       0.0
# max          0.000000             0.995900  19692.000000       0.0
#
#             units  instruction_mode
# count  970.000000               0.0
# mean     3.843299               NaN
# std      0.913256               NaN
# min      0.000000               NaN
# 25%      4.000000               NaN
# 50%      4.000000               NaN
# 75%      4.000000               NaN
# max      8.000000               NaN

# %%
df['course_id'] = df['course_id'].astype(str)

# %%
df.head()
# Out:
#      course_code                                  course_title_2024  \
# 0   AFRAMER 133Y  The Politics of Paradise: Tourism in Latin Ame...
# 1   AFRAMER 146X      A Black History of Electronic Dance Music 001
# 2    AFRAMER 197                      Poverty, Race, and Health 001
# 3  AMHARIC 101AR                               Advanced Amharic 001
# 4        IGBO AA                                Elementary Igbo 001
#
#   course_teacher                                               link  \
# 0          Henry  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 1       aumoithe  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 2       Williams  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 3         Mugane  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 4         Mugane  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                   fas_code                        unique_code course_id  \
# 0  FAS-224623-2248-1-1-001     FAS-224623-2248-1-1-001(Henry)    224623
# 1  FAS-222657-2248-1-1-001  FAS-222657-2248-1-1-001(aumoithe)    222657
# 2  FAS-123435-2248-1-1-001  FAS-123435-2248-1-1-001(Williams)    123435
# 3  FAS-205845-2248-1-1-001    FAS-205845-2248-1-1-001(Mugane)    205845
# 4  FAS-126308-2248-1-1-001    FAS-126308-2248-1-1-001(Mugane)    126308
#
#    num_responded  num_students  course_score_mean  course_score_median  \
# 0              7             7               5.00                  5.0
# 1              8            11               4.38                  5.0
# 2             32            38               4.72                  5.0
# 3              5             6               4.75                  5.0
# 4              6             9               4.00                  4.0
#
#    course_score_mode  course_score_stdev  lecturer_score_mean  \
# 0                5.0            0.000000                 5.00
# 1                5.0            0.858504                 4.63
# 2                5.0            0.509605                 4.89
# 3                5.0            0.435194                 0.00
# 4                3.0            0.820652                 0.00
#
#    lecturer_score_median  lecturer_score_mode  lecturer_score_stdev  \
# 0                    5.0                  5.0              0.000000
# 1                    5.0                  5.0              0.486857
# 2                    5.0                  5.0              0.314466
# 3                    0.0                  0.0             -1.000000
# 4                    0.0                  0.0             -1.000000
#
#    workload_score_mean  workload_score_median  workload_score_mode  \
# 0                 4.43                    4.0                  4.0
# 1                 6.00                    4.0                  3.0
# 2                 4.67                    4.0                  3.0
# 3                 2.67                    3.0                  3.0
# 4                 5.50                    4.5                  4.0
#
#    workload_score_stdev  rec_score_mean  rec_score_median  rec_score_mode  \
# 0                  1.72            5.00               5.0             5.0
# 1                  4.38            4.63               5.0             5.0
# 2                  2.62            4.83               5.0             5.0
# 3                  0.58            5.00               5.0             5.0
# 4                  2.35            4.40               4.0             4.0
#
#    rec_score_stdev  sentiment_score_mean  sentiment_score_median  \
# 0             0.00              0.911167                 0.92860
# 1             0.52              0.894640                 0.88030
# 2             0.38              0.795317                 0.95470
# 3             0.00              0.000000                 0.00000
# 4             0.55              0.502450                 0.76905
#
#    sentiment_score_mode  sentiment_score_stdev  gem_probability_mean  \
# 0                0.9748               0.065004              0.000000
# 1                0.9449               0.079440              0.000000
# 2                0.9409               0.368350              0.083333
# 3                0.0000               0.000000              0.000000
# 4                0.8481               0.620971              0.000000
#
#    gem_probability_median  gem_probability_mode  gem_probability_stdev  \
# 0                     0.0                   0.0               0.000000
# 1                     0.0                   0.0               0.000000
# 2                     0.0                   0.0               0.288675
# 3                     0.0                   0.0               0.000000
# 4                     0.0                   0.0               0.000000
#
#                                         best_comment  max_sent_score  \
# 0  TAKE THIS CLASS! The best course I have taken ...          0.9748
# 1  This course was awesome. I added new music to ...          0.9935
# 2  I think you should definitely TAKE THIS CLASSS...          0.9959
# 3                                                NaN          0.0000
# 4  this class is fun and you definitely get what ...          0.8916
#
#                                        worse_comment  min_sent_score  \
# 0                                                NaN          0.0000
# 1                                                NaN          0.0000
# 2  There is not a lot of engagement in lectures, ...         -0.1877
# 3                                                NaN          0.0000
# 4  Approach everything with an open mind and don'...         -0.4199
#
#                                     best_gem_comment  max_gem_probability  \
# 0                                                NaN               0.0000
# 1                                                NaN               0.0000
# 2  I think you should definitely TAKE THIS CLASSS...               0.9959
# 3                                                NaN               0.0000
# 4                                                NaN               0.0000
#
#                                    course_title_2025 subject_catalog  \
# 0  The Politics of Paradise: Tourism in Latin Ame...   AFRAMER  133Y
# 1          A Black History of Electronic Dance Music   AFRAMER  146X
# 2                          Poverty, Race, and Health    AFRAMER  197
# 3                                   Advanced Amharic  AMHARIC  101AR
# 4                                    Elementary Igbo     IGBO     AA
#
#        instructors  year_term  term_type  start_date    end_date start_time  \
# 0      Amber Henry  2025 Fall  Full Term  2025-09-02  2025-12-03    12:00pm
# 1  george aumoithe  2025 Fall  Full Term  2025-09-02  2025-12-03    12:00pm
# 2   David Williams  2025 Fall  Full Term  2025-09-02  2025-12-03    12:45pm
# 3      John Mugane  2025 Fall  Full Term  2025-09-02  2025-12-03        NaN
# 4      John Mugane  2025 Fall  Full Term  2025-09-02  2025-12-03        NaN
#
#   end_time weekdays  class_number     consent enrolled  waitlist  \
# 0   2:45pm      Tue         15920  Instructor     0/30         0
# 1   2:45pm      Wed         15947  No Consent        0         0
# 2   2:45pm      Tue         13718  No Consent        0         0
# 3      NaN      NaN         13873  Department     0/15         0
# 4      NaN      NaN         12357  Department     0/15         0
#
#    lecture_sunday  lecture_monday  lecture_tuesday  lecture_wednesday  \
# 0           False           False             True              False
# 1           False           False            False               True
# 2           False           False             True              False
# 3           False           False            False              False
# 4           False           False            False              False
#
#    lecture_thursday  lecture_friday  lecture_saturday  \
# 0             False           False             False
# 1             False           False             False
# 2             False           False             False
# 3             False           False             False
# 4             False           False             False
#
#                                          description  \
# 0  What does tourism sell? How do destination ima...
# 1  Electronic dance music. Mentioning the genre e...
# 2  This course critically examines the health sta...
# 3  A study of Amharic the statutory national lang...
# 4  A study of Igbo one of the three most widely s...
#
#                                                notes  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Languages in the tutorial program are offered ...
# 4  Languages in the tutorial program are offered ...
#
#                        school  units  \
# 0  Faculty of Arts & Sciences      4
# 1  Faculty of Arts & Sciences      4
# 2  Faculty of Arts & Sciences      4
# 3  Faculty of Arts & Sciences      4
# 4  Faculty of Arts & Sciences      4
#
#                          cross_registration                      department  \
# 0  Available for Harvard Cross Registration  African & African Amer Studies
# 1  Available for Harvard Cross Registration  African & African Amer Studies
# 2  Available for Harvard Cross Registration  African & African Amer Studies
# 3  Available for Harvard Cross Registration  African & African Amer Studies
# 4  Available for Harvard Cross Registration  African & African Amer Studies
#
#   course_component  instruction_mode      grading_basis  \
# 0          Lecture               NaN  FAS Letter Graded
# 1          Seminar               NaN  FAS Letter Graded
# 2          Lecture               NaN  FAS Letter Graded
# 3          Seminar               NaN  FAS Letter Graded
# 4          Seminar               NaN  FAS Letter Graded
#
#                           course_requirements general_education  \
# 0                                         NaN               NaN
# 1                                         NaN               NaN
# 2  Course open to Undergraduate Students Only               NaN
# 3                                         NaN               NaN
# 4                                         NaN               NaN
#
#   quantitative_reasoning divisional_distribution
# 0                    NaN         Social Sciences
# 1                    NaN     Arts and Humanities
# 2                    NaN         Social Sciences
# 3                    NaN     Arts and Humanities
# 4                    NaN                    None

# %%
df['course_identifier'] = df['course_code'] + ' ' + df[f'course_title_{myharvard_year}']
df = df.drop_duplicates(subset='course_identifier', keep="first")

# %%
df.nlargest(5,'sentiment_score_mean')
# Out:
#     course_code                       course_title_2024 course_teacher  \
# 142  JAPAN 130A            Intermediate Japanese II 001       Takehara
# 716   ARABIC AA                 Elementary Arabic I 001         Malhas
# 965   WOMGEN 97           Tutorial - Sophomore Year 001    Schlossberg
# 52      BPH 219  Biological Sciences Communications 001          Nagel
# 707     MCB 297                    Method and Logic 001       Olveczky
#
#                                                   link  \
# 142  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 716  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 965  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 52   https://harvard.bluera.com/harvard/rpv-eng.asp...
# 707  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                           unique_code course_id  \
# 142  FAS-114292-2248-1-1-001     FAS-114292-2248-1-1-001(Takehara)    114292
# 716  FAS-116746-2248-1-1-001       FAS-116746-2248-1-1-001(Malhas)    116746
# 965  FAS-120677-2248-1-1-001  FAS-120677-2248-1-1-001(Schlossberg)    120677
# 52   FAS-110521-2248-1-1-001        FAS-110521-2248-1-1-001(Nagel)    110521
# 707  FAS-223831-2248-1-1-001     FAS-223831-2248-1-1-001(Olveczky)    223831
#
#      num_responded  num_students  course_score_mean  course_score_median  \
# 142              5            11               4.80                  5.0
# 716             10            13               4.56                  5.0
# 965              9            10               4.75                  5.0
# 52               5            12               4.00                  4.0
# 707              6             7               3.60                  4.0
#
#      course_score_mode  course_score_stdev  lecturer_score_mean  \
# 142                5.0            0.402015                 5.00
# 716                5.0            0.686375                 4.88
# 965                5.0            0.435194                 5.00
# 52                 4.0            0.000000                 3.75
# 707                4.0            0.492366                 4.20
#
#      lecturer_score_median  lecturer_score_mode  lecturer_score_stdev  \
# 142                    5.0                  5.0              0.000000
# 716                    5.0                  5.0              0.336552
# 965                    5.0                  5.0              0.000000
# 52                     4.0                  4.0              0.435194
# 707                    4.0                  4.0              0.752101
#
#      workload_score_mean  workload_score_median  workload_score_mode  \
# 142                 7.60                    7.0                 12.0
# 716                11.44                   10.0                 10.0
# 965                 7.57                    7.0                  8.0
# 52                  4.00                    4.0                  4.0
# 707                 9.00                   10.0                 10.0
#
#      workload_score_stdev  rec_score_mean  rec_score_median  rec_score_mode  \
# 142                  2.70            4.60               5.0             5.0
# 716                  6.86            4.75               5.0             5.0
# 965                  3.60            4.75               5.0             5.0
# 52                   0.82            4.00               4.0             4.0
# 707                  2.45            3.20               3.0             3.0
#
#      rec_score_stdev  sentiment_score_mean  sentiment_score_median  \
# 142             0.55              0.998400                 0.99840
# 716             0.46              0.990150                 0.99015
# 965             0.46              0.971675                 0.97750
# 52              0.00              0.969400                 0.96940
# 707             0.45              0.967400                 0.96740
#
#      sentiment_score_mode  sentiment_score_stdev  gem_probability_mean  \
# 142                0.9984               -1.00000                   0.0
# 716                0.9852                0.00700                   0.0
# 965                0.9833                0.01876                   0.0
# 52                 0.9694               -1.00000                   0.0
# 707                0.9674               -1.00000                   0.0
#
#      gem_probability_median  gem_probability_mode  gem_probability_stdev  \
# 142                     0.0                   0.0                   -1.0
# 716                     0.0                   0.0                    0.0
# 965                     0.0                   0.0                    0.0
# 52                      0.0                   0.0                   -1.0
# 707                     0.0                   0.0                   -1.0
#
#                                           best_comment  max_sent_score  \
# 142  楽しすぎったよ！竹原先生と仲谷先生はいつも最高だ。10/10 course. Japanes...          0.9984
# 716  Coming from a native/heritage/at–home Arabic s...          0.9951
# 965  I think this was an awesome class, and I espec...          0.9865
# 52   Excellent course to practice science communica...          0.9694
# 707  At first you will find it challenging to read ...          0.9674
#
#     worse_comment  min_sent_score best_gem_comment  max_gem_probability  \
# 142           NaN             0.0              NaN                  0.0
# 716           NaN             0.0              NaN                  0.0
# 965           NaN             0.0              NaN                  0.0
# 52            NaN             0.0              NaN                  0.0
# 707           NaN             0.0              NaN                  0.0
#
#                       course_title_2025    subject_catalog       instructors  \
# 142            Intermediate Japanese II    JAPAN  130A 001  Chikako Takehara
# 716                 Elementary Arabic I  ARABIC     AA 003   Richard Cozzens
# 965           Tutorial - Sophomore Year        WOMGEN   97   Michael Bronski
# 52   Biological Sciences Communications           BPH  219     Zachary Nagel
# 707                    Method and Logic       MCB  297 002      Ethan Garner
#
#      year_term  term_type  start_date    end_date start_time end_time  \
# 142  2025 Fall  Full Term  2025-09-02  2025-12-03     9:00am  10:15am
# 716  2025 Fall  Full Term  2025-09-02  2025-12-03    12:00pm   1:15pm
# 965  2025 Fall  Full Term  2025-09-02  2025-12-03    10:30am  11:45am
# 52   2025 Fall  Full Term  2025-09-02  2025-12-03     2:30pm   4:00pm
# 707  2025 Fall  Full Term  2025-09-02  2025-12-03    12:45pm   2:45pm
#
#             weekdays  class_number     consent enrolled  waitlist  \
# 142  Mon Tue Thu Fri         11384  No Consent        0         0
# 716  Mon Tue Wed Thu         12468  Instructor     0/12         0
# 965          Tue Thu         12925  Instructor     0/15         0
# 52           Mon Wed         10650  Instructor        0         0
# 707              Wed         15289  Instructor     0/20         0
#
#      lecture_sunday  lecture_monday  lecture_tuesday  lecture_wednesday  \
# 142           False            True             True              False
# 716           False            True             True               True
# 965           False           False             True              False
# 52            False            True            False               True
# 707           False           False            False               True
#
#      lecture_thursday  lecture_friday  lecture_saturday  \
# 142              True            True             False
# 716              True           False             False
# 965              True           False             False
# 52              False           False             False
# 707             False           False             False
#
#                                            description  \
# 142  Third-year intermediate advanced course. Devel...
# 716  Introduces students to the phonology and scrip...
# 965  An introduction to foundational concepts, key ...
# 52   Emphasis of this course is effective scientifi...
# 707  Each of the four Method and Logic courses are ...
#
#                                                  notes  \
# 142                                                NaN
# 716  Offered jointly with the Divinity School as 43...
# 965  Required of Women, Gender, and Sexuality conce...
# 52   Course intended for first year BPH PhD student...
# 707                                                NaN
#
#                          school  units  \
# 142  Faculty of Arts & Sciences      4
# 716  Faculty of Arts & Sciences      4
# 965  Faculty of Arts & Sciences      4
# 52   Faculty of Arts & Sciences      4
# 707  Faculty of Arts & Sciences      4
#
#                            cross_registration                     department  \
# 142  Available for Harvard Cross Registration         East Asian Langs & Civ
# 716  Available for Harvard Cross Registration   Near Eastern Languages & Civ
# 965      Not Available for Cross Registration      Women, Gender & Sexuality
# 52   Available for Harvard Cross Registration  Bio Sciences in Public Health
# 707  Available for Harvard Cross Registration   Molecular & Cellular Biology
#
#     course_component  instruction_mode      grading_basis course_requirements  \
# 142          Lecture               NaN  FAS Letter Graded                 NaN
# 716          Lecture               NaN  FAS Letter Graded                 NaN
# 965         Tutorial               NaN  FAS Letter Graded                 NaN
# 52           Seminar               NaN  FAS Letter Graded                 NaN
# 707       Discussion               NaN  FAS Letter Graded                 NaN
#
#     general_education quantitative_reasoning  \
# 142               NaN                    NaN
# 716               NaN                    NaN
# 965               NaN                    NaN
# 52                NaN                    NaN
# 707               NaN                    NaN
#
#                      divisional_distribution  \
# 142                                     None
# 716                                     None
# 965                          Social Sciences
# 52                                      None
# 707  Science & Engineering & Applied Science
#
#                               course_identifier
# 142         JAPAN 130A Intermediate Japanese II
# 716               ARABIC AA Elementary Arabic I
# 965         WOMGEN 97 Tutorial - Sophomore Year
# 52   BPH 219 Biological Sciences Communications
# 707                    MCB 297 Method and Logic

# %%
import re
from nltk import tokenize
import nltk
nltk.download('punkt')

df['best_gem_comment'].fillna('',inplace=True)

def get_short_gem_comment(comment):
  if comment == '':
    return ''
  for sentence in tokenize.sent_tokenize(comment):
    if re.search(r'\bgem\b',sentence.lower()):
      return sentence
  assert False


df['best_gem_comment_short'] = df['best_gem_comment'].apply(get_short_gem_comment)
# Out:
# [nltk_data] Downloading package punkt to /Users/jeqcho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()

df['best_comment'].fillna('',inplace=True)

def get_short_comment(comment):
  if comment == '':
    return ''
  max_score = 0
  best_short_comment = ''
  for sentence in tokenize.sent_tokenize(comment):
    score = sia.polarity_scores(sentence)['compound']
    if score > max_score:
      max_score = score
      best_short_comment = sentence
  return best_short_comment


df['best_comment_short'] = df['best_comment'].apply(get_short_comment)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jeqcho/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def get_first_sentece(comment):
  if comment == '':
    return ''
  return tokenize.sent_tokenize(comment)[0]


df['best_comment_first'] = df['best_comment'].apply(get_first_sentece)

# %%
plt.scatter(df['num_students'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('num_students')
plt.ylabel('course_score_mean')
plt.gca().set_facecolor('white')
# Show the plot
plt.show()

# %%
plt.scatter(df['lecturer_score_mean'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('lecturer_score_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()

# %%
plt.scatter(df['rec_score_mean'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('rec_score_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()

# %%
plt.scatter(df['sentiment_score_mean'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('sentiment_score_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()

# %%
plt.scatter(df['gem_probability_mean'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('gem_probability_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()

# %%
df_course_gem = df[df['gem_probability_mean'] > 0]
df_course_gem = df_course_gem[df_course_gem['gem_probability_mean'] < 1]
print(len(df_course_gem))
plt.scatter(df_course_gem['gem_probability_mean'], df_course_gem['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('gem_probability_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()
# Out:
# 36

# %%
plt.scatter(df['workload_score_mean'], df['course_score_mean'])

# Add x-axis and y-axis labels
plt.xlabel('workload_score_mean')
plt.ylabel('course_score_mean')

# Show the plot
plt.show()

# %%
plt.hist(df['course_score_mean'], rwidth=.5)

# Add x-axis and y-axis labels
plt.xlabel('course_score_mean')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.hist(df['course_score_mean'],bins=20)

# Add x-axis and y-axis labels
plt.xlabel('course_score_mean')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.hist(df['course_score_median'])

# Add x-axis and y-axis labels
plt.xlabel('course_score_median')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.hist(df['lecturer_score_mean'],bins=40)

# Add x-axis and y-axis labels
plt.xlabel('lecturer_score_mean')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.hist(df['workload_score_mean'],bins=40)

# Add x-axis and y-axis labels
plt.xlabel('workload_score_mean')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
df['num_students'].describe()
# Out:
# count    515.000000
# mean      35.737864
# std       65.403739
# min        5.000000
# 25%       10.000000
# 50%       15.000000
# 75%       30.500000
# max      735.000000
# Name: num_students, dtype: float64

# %%
import numpy

df_super_gem = df[(df['course_score_median'] == 5)
& (df['lecturer_score_median'] == 5)
& (df['rec_score_median'] == 5)
& (df['gem_probability_mean'] > 0)
& (df['num_responded']/df['num_students'] >= 0.8-0.1*numpy.log2(df['num_students']/10))
& (df['course_id'] != '-1')
]

print(len(df_super_gem))
df_super_gem = df_super_gem.sort_values(by=['gem_probability_mean'],ascending=False)
df_super_gem.head()
# Out:
# 19
#      course_code                                  course_title_2024  \
# 273     EMR 1010  Topics in Latinx Studies: Introduction to Lati...
# 723  ARABIC 131A                    Upper-Level Modern Arabic l 001
# 851      ITAL 40  Advanced Italian I: Italian Through Cinema: Or...
# 479      HEB 123   Dogs: Behavior, evolution, and domestication 001
# 369   FYSEMR 52Z  Attention Deficit Hyperactivity Disorder (ADHD...
#
#     course_teacher                                               link  \
# 273    Bouso Gavin  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 723   Khalaf Ahmed  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 851    Trebaiocchi  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 479          Hecht  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 369         Arnett  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                            unique_code course_id  \
# 273  FAS-218600-2248-1-1-001   FAS-218600-2248-1-1-001(Bouso Gavin)    218600
# 723  FAS-121346-2248-1-1-001  FAS-121346-2248-1-1-001(Khalaf Ahmed)    121346
# 851  FAS-116233-2248-1-1-001   FAS-116233-2248-1-1-001(Trebaiocchi)    116233
# 479  FAS-220650-2248-1-1-001         FAS-220650-2248-1-1-001(Hecht)    220650
# 369  FAS-224001-2248-1-1-001        FAS-224001-2248-1-1-001(Arnett)    224001
#
#      num_responded  num_students  course_score_mean  course_score_median  \
# 273              5             5               4.80                  5.0
# 723              7             7               4.57                  5.0
# 851              9            10               4.78                  5.0
# 479             11            12               5.00                  5.0
# 369             13            13               4.38                  5.0
#
#      course_score_mode  course_score_stdev  lecturer_score_mean  \
# 273                5.0            0.402015                 4.75
# 723                5.0            0.729704                 5.00
# 851                5.0            0.416333                 4.89
# 479                5.0            0.000000                 5.00
# 369                5.0            0.737111                 4.69
#
#      lecturer_score_median  lecturer_score_mode  lecturer_score_stdev  \
# 273                    5.0                  5.0              0.435194
# 723                    5.0                  5.0              0.000000
# 851                    5.0                  5.0              0.314466
# 479                    5.0                  5.0              0.000000
# 369                    5.0                  5.0              0.614554
#
#      workload_score_mean  workload_score_median  workload_score_mode  \
# 273                 3.20                    3.0                  3.0
# 723                 9.83                   10.0                 16.0
# 851                 7.88                    6.0                  5.0
# 479                 4.11                    3.0                  3.0
# 369                 3.42                    2.0                  1.0
#
#      workload_score_stdev  rec_score_mean  rec_score_median  rec_score_mode  \
# 273                  1.10            4.75               5.0             5.0
# 723                  5.34            4.57               5.0             5.0
# 851                  3.60            4.78               5.0             5.0
# 479                  4.28            5.00               5.0             5.0
# 369                  4.08            4.69               5.0             5.0
#
#      rec_score_stdev  sentiment_score_mean  sentiment_score_median  \
# 273             0.50              0.687100                 0.65880
# 723             0.79              0.785350                 0.81445
# 851             0.67              0.745940                 0.91630
# 479             0.00              0.876057                 0.93670
# 369             0.48              0.867075                 0.90905
#
#      sentiment_score_mode  sentiment_score_stdev  gem_probability_mean  \
# 273                0.9621               0.261999              0.333333
# 723                0.5267               0.234511              0.250000
# 851                0.9595               0.370604              0.200000
# 479                0.6249               0.127018              0.142857
# 369                0.9640               0.133793              0.125000
#
#      gem_probability_median  gem_probability_mode  gem_probability_stdev  \
# 273                     0.0                   0.0               0.577350
# 723                     0.0                   0.0               0.500000
# 851                     0.0                   0.0               0.447214
# 479                     0.0                   0.0               0.377964
# 369                     0.0                   0.0               0.353553
#
#                                           best_comment  max_sent_score  \
# 273  PLEASE TAKE THIS COURSE! You absolutely will n...          0.9621
# 723  I would strongly, STRONGLY recommend continuin...          0.9858
# 851  TAKE THIS CLASS!! This is by far my favorite I...          0.9926
# 479  This class is such a great opportunity. Where ...          0.9819
# 369  TAKE this class. This is the best class! Reall...          0.9640
#
#     worse_comment  min_sent_score  \
# 273           NaN             0.0
# 723           NaN             0.0
# 851           NaN             0.0
# 479           NaN             0.0
# 369           NaN             0.0
#
#                                       best_gem_comment  max_gem_probability  \
# 273  Absolutely take this class – total gem! You wi...               0.6588
# 723  Ustaadha Aya is a Harvard gem of a teacher! Sh...               0.9821
# 851  This class is so fun––you get to watch movies ...               0.9163
# 479  TAKE THIS CLASS, a true gem. Erin and Sophie a...               0.9367
# 369  TAKE THIS COURSE!!! If you have any interest i...               0.9619
#
#                                      course_title_2025   subject_catalog  \
# 273  Topics in Latinx Studies: Latinx Literature an...          EMR 1010
# 723                        Upper-Level Modern Arabic l  ARABIC  131A 001
# 851  Advanced Italian I: Italian Through Cinema: Or...         ITAL   40
# 479       Dogs: Behavior, evolution, and domestication          HEB  123
# 369  Attention Deficit Hyperactivity Disorder (ADHD...      FYSEMR   52Z
#
#             instructors  year_term  term_type  start_date    end_date  \
# 273   Aitor Bouso Gavin  2025 Fall  Full Term  2025-09-02  2025-12-03
# 723            Amr Madi  2025 Fall  Full Term  2025-09-02  2025-12-03
# 851  Chiara Trebaiocchi  2025 Fall  Full Term  2025-09-02  2025-12-03
# 479          Erin Hecht  2025 Fall  Full Term  2025-09-02  2025-12-03
# 369         Anne Arnett  2025 Fall  Full Term  2025-09-02  2025-12-03
#
#     start_time end_time         weekdays  class_number     consent enrolled  \
# 273    12:00pm   1:15pm          Tue Thu         13216  No Consent        0
# 723    10:30am  11:45am  Mon Tue Wed Thu         11343  Instructor     0/12
# 851    12:00pm   1:15pm          Tue Thu         12853  No Consent        0
# 479     1:30pm   2:45pm          Tue Thu         13551  Instructor     0/12
# 369     3:00pm   5:00pm              Wed         15412  Instructor     0/15
#
#      waitlist  lecture_sunday  lecture_monday  lecture_tuesday  \
# 273         0           False           False             True
# 723         0           False            True             True
# 851         0           False           False             True
# 479         0           False           False             True
# 369         0           False           False            False
#
#      lecture_wednesday  lecture_thursday  lecture_friday  lecture_saturday  \
# 273              False              True           False             False
# 723               True              True           False             False
# 851              False              True           False             False
# 479              False              True           False             False
# 369               True             False           False             False
#
#                                            description  \
# 273  This is a broad-based course that utilizes art...
# 723  Reading and discussion of selections from Arab...
# 851  Through the exploration of both old and contem...
# 479  What makes dogs behave the way they do, and wh...
# 369  This first-year seminar will dive into the sci...
#
#                                                  notes  \
# 273                                                NaN
# 723                              Not open to auditors.
# 851  Conducted in Italian. May not be taken Pass/Fa...
# 479  Dog behavior data will be collected on campus ...
# 369                                                NaN
#
#                          school  units  \
# 273  Faculty of Arts & Sciences      4
# 723  Faculty of Arts & Sciences      4
# 851  Faculty of Arts & Sciences      4
# 479  Faculty of Arts & Sciences      4
# 369  Faculty of Arts & Sciences      4
#
#                            cross_registration                    department  \
# 273  Available for Harvard Cross Registration  Ethnicity, Migration, Rights
# 723  Available for Harvard Cross Registration  Near Eastern Languages & Civ
# 851  Available for Harvard Cross Registration       Romance Languages & Lit
# 479  Available for Harvard Cross Registration    Human Evolutionary Biology
# 369      Not Available for Cross Registration    First Year Seminar Program
#
#     course_component  instruction_mode                    grading_basis  \
# 273          Lecture               NaN                FAS Letter Graded
# 723          Lecture               NaN                FAS Letter Graded
# 851          Lecture               NaN                FAS Letter Graded
# 479          Seminar               NaN                FAS Letter Graded
# 369          Seminar               NaN  FAS Satisfactory/Unsatisfactory
#
#                        course_requirements general_education  \
# 273                                    NaN               NaN
# 723                                    NaN               NaN
# 851                                    NaN               NaN
# 479                                    NaN               NaN
# 369  Course open to Freshman Students Only               NaN
#
#     quantitative_reasoning                  divisional_distribution  \
# 273                    NaN                      Arts and Humanities
# 723                    NaN                      Arts and Humanities
# 851                    NaN                      Arts and Humanities
# 479                    NaN  Science & Engineering & Applied Science
# 369                    NaN                                     None
#
#                                      course_identifier  \
# 273  EMR 1010 Topics in Latinx Studies: Latinx Lite...
# 723            ARABIC 131A Upper-Level Modern Arabic l
# 851  ITAL 40 Advanced Italian I: Italian Through Ci...
# 479  HEB 123 Dogs: Behavior, evolution, and domesti...
# 369  FYSEMR 52Z Attention Deficit Hyperactivity Dis...
#
#                                 best_gem_comment_short  \
# 273            Absolutely take this class – total gem!
# 723        Ustaadha Aya is a Harvard gem of a teacher!
# 851  Chiara is a gem, but can be kind of a tough gr...
# 479                       TAKE THIS CLASS, a true gem.
# 369  It's a gem for sure, the debates are engaging,...
#
#                                     best_comment_short  \
# 273  It's a very enlightening and super fun course ...
# 723  Every day she shows up with a huge amount of e...
# 851  It was also so wonderful to take a course with...
# 479  Really cool to be exposed to lab work with liv...
# 369  Really great and passionate professor :) Made ...
#
#                                     best_comment_first
# 273                           PLEASE TAKE THIS COURSE!
# 723  I would strongly, STRONGLY recommend continuin...
# 851                                  TAKE THIS CLASS!!
# 479            This class is such a great opportunity.
# 369                                   TAKE this class.

# %%
df_super_gem = df_super_gem[df_super_gem['course_code'] != 'EXPOS 20']
df_super_gem.head()
# Out:
#      course_code                                  course_title_2024  \
# 273     EMR 1010  Topics in Latinx Studies: Introduction to Lati...
# 723  ARABIC 131A                    Upper-Level Modern Arabic l 001
# 851      ITAL 40  Advanced Italian I: Italian Through Cinema: Or...
# 479      HEB 123   Dogs: Behavior, evolution, and domestication 001
# 369   FYSEMR 52Z  Attention Deficit Hyperactivity Disorder (ADHD...
#
#     course_teacher                                               link  \
# 273    Bouso Gavin  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 723   Khalaf Ahmed  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 851    Trebaiocchi  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 479          Hecht  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 369         Arnett  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                            unique_code course_id  \
# 273  FAS-218600-2248-1-1-001   FAS-218600-2248-1-1-001(Bouso Gavin)    218600
# 723  FAS-121346-2248-1-1-001  FAS-121346-2248-1-1-001(Khalaf Ahmed)    121346
# 851  FAS-116233-2248-1-1-001   FAS-116233-2248-1-1-001(Trebaiocchi)    116233
# 479  FAS-220650-2248-1-1-001         FAS-220650-2248-1-1-001(Hecht)    220650
# 369  FAS-224001-2248-1-1-001        FAS-224001-2248-1-1-001(Arnett)    224001
#
#      num_responded  num_students  course_score_mean  course_score_median  \
# 273              5             5               4.80                  5.0
# 723              7             7               4.57                  5.0
# 851              9            10               4.78                  5.0
# 479             11            12               5.00                  5.0
# 369             13            13               4.38                  5.0
#
#      course_score_mode  course_score_stdev  lecturer_score_mean  \
# 273                5.0            0.402015                 4.75
# 723                5.0            0.729704                 5.00
# 851                5.0            0.416333                 4.89
# 479                5.0            0.000000                 5.00
# 369                5.0            0.737111                 4.69
#
#      lecturer_score_median  lecturer_score_mode  lecturer_score_stdev  \
# 273                    5.0                  5.0              0.435194
# 723                    5.0                  5.0              0.000000
# 851                    5.0                  5.0              0.314466
# 479                    5.0                  5.0              0.000000
# 369                    5.0                  5.0              0.614554
#
#      workload_score_mean  workload_score_median  workload_score_mode  \
# 273                 3.20                    3.0                  3.0
# 723                 9.83                   10.0                 16.0
# 851                 7.88                    6.0                  5.0
# 479                 4.11                    3.0                  3.0
# 369                 3.42                    2.0                  1.0
#
#      workload_score_stdev  rec_score_mean  rec_score_median  rec_score_mode  \
# 273                  1.10            4.75               5.0             5.0
# 723                  5.34            4.57               5.0             5.0
# 851                  3.60            4.78               5.0             5.0
# 479                  4.28            5.00               5.0             5.0
# 369                  4.08            4.69               5.0             5.0
#
#      rec_score_stdev  sentiment_score_mean  sentiment_score_median  \
# 273             0.50              0.687100                 0.65880
# 723             0.79              0.785350                 0.81445
# 851             0.67              0.745940                 0.91630
# 479             0.00              0.876057                 0.93670
# 369             0.48              0.867075                 0.90905
#
#      sentiment_score_mode  sentiment_score_stdev  gem_probability_mean  \
# 273                0.9621               0.261999              0.333333
# 723                0.5267               0.234511              0.250000
# 851                0.9595               0.370604              0.200000
# 479                0.6249               0.127018              0.142857
# 369                0.9640               0.133793              0.125000
#
#      gem_probability_median  gem_probability_mode  gem_probability_stdev  \
# 273                     0.0                   0.0               0.577350
# 723                     0.0                   0.0               0.500000
# 851                     0.0                   0.0               0.447214
# 479                     0.0                   0.0               0.377964
# 369                     0.0                   0.0               0.353553
#
#                                           best_comment  max_sent_score  \
# 273  PLEASE TAKE THIS COURSE! You absolutely will n...          0.9621
# 723  I would strongly, STRONGLY recommend continuin...          0.9858
# 851  TAKE THIS CLASS!! This is by far my favorite I...          0.9926
# 479  This class is such a great opportunity. Where ...          0.9819
# 369  TAKE this class. This is the best class! Reall...          0.9640
#
#     worse_comment  min_sent_score  \
# 273           NaN             0.0
# 723           NaN             0.0
# 851           NaN             0.0
# 479           NaN             0.0
# 369           NaN             0.0
#
#                                       best_gem_comment  max_gem_probability  \
# 273  Absolutely take this class – total gem! You wi...               0.6588
# 723  Ustaadha Aya is a Harvard gem of a teacher! Sh...               0.9821
# 851  This class is so fun––you get to watch movies ...               0.9163
# 479  TAKE THIS CLASS, a true gem. Erin and Sophie a...               0.9367
# 369  TAKE THIS COURSE!!! If you have any interest i...               0.9619
#
#                                      course_title_2025   subject_catalog  \
# 273  Topics in Latinx Studies: Latinx Literature an...          EMR 1010
# 723                        Upper-Level Modern Arabic l  ARABIC  131A 001
# 851  Advanced Italian I: Italian Through Cinema: Or...         ITAL   40
# 479       Dogs: Behavior, evolution, and domestication          HEB  123
# 369  Attention Deficit Hyperactivity Disorder (ADHD...      FYSEMR   52Z
#
#             instructors  year_term  term_type  start_date    end_date  \
# 273   Aitor Bouso Gavin  2025 Fall  Full Term  2025-09-02  2025-12-03
# 723            Amr Madi  2025 Fall  Full Term  2025-09-02  2025-12-03
# 851  Chiara Trebaiocchi  2025 Fall  Full Term  2025-09-02  2025-12-03
# 479          Erin Hecht  2025 Fall  Full Term  2025-09-02  2025-12-03
# 369         Anne Arnett  2025 Fall  Full Term  2025-09-02  2025-12-03
#
#     start_time end_time         weekdays  class_number     consent enrolled  \
# 273    12:00pm   1:15pm          Tue Thu         13216  No Consent        0
# 723    10:30am  11:45am  Mon Tue Wed Thu         11343  Instructor     0/12
# 851    12:00pm   1:15pm          Tue Thu         12853  No Consent        0
# 479     1:30pm   2:45pm          Tue Thu         13551  Instructor     0/12
# 369     3:00pm   5:00pm              Wed         15412  Instructor     0/15
#
#      waitlist  lecture_sunday  lecture_monday  lecture_tuesday  \
# 273         0           False           False             True
# 723         0           False            True             True
# 851         0           False           False             True
# 479         0           False           False             True
# 369         0           False           False            False
#
#      lecture_wednesday  lecture_thursday  lecture_friday  lecture_saturday  \
# 273              False              True           False             False
# 723               True              True           False             False
# 851              False              True           False             False
# 479              False              True           False             False
# 369               True             False           False             False
#
#                                            description  \
# 273  This is a broad-based course that utilizes art...
# 723  Reading and discussion of selections from Arab...
# 851  Through the exploration of both old and contem...
# 479  What makes dogs behave the way they do, and wh...
# 369  This first-year seminar will dive into the sci...
#
#                                                  notes  \
# 273                                                NaN
# 723                              Not open to auditors.
# 851  Conducted in Italian. May not be taken Pass/Fa...
# 479  Dog behavior data will be collected on campus ...
# 369                                                NaN
#
#                          school  units  \
# 273  Faculty of Arts & Sciences      4
# 723  Faculty of Arts & Sciences      4
# 851  Faculty of Arts & Sciences      4
# 479  Faculty of Arts & Sciences      4
# 369  Faculty of Arts & Sciences      4
#
#                            cross_registration                    department  \
# 273  Available for Harvard Cross Registration  Ethnicity, Migration, Rights
# 723  Available for Harvard Cross Registration  Near Eastern Languages & Civ
# 851  Available for Harvard Cross Registration       Romance Languages & Lit
# 479  Available for Harvard Cross Registration    Human Evolutionary Biology
# 369      Not Available for Cross Registration    First Year Seminar Program
#
#     course_component  instruction_mode                    grading_basis  \
# 273          Lecture               NaN                FAS Letter Graded
# 723          Lecture               NaN                FAS Letter Graded
# 851          Lecture               NaN                FAS Letter Graded
# 479          Seminar               NaN                FAS Letter Graded
# 369          Seminar               NaN  FAS Satisfactory/Unsatisfactory
#
#                        course_requirements general_education  \
# 273                                    NaN               NaN
# 723                                    NaN               NaN
# 851                                    NaN               NaN
# 479                                    NaN               NaN
# 369  Course open to Freshman Students Only               NaN
#
#     quantitative_reasoning                  divisional_distribution  \
# 273                    NaN                      Arts and Humanities
# 723                    NaN                      Arts and Humanities
# 851                    NaN                      Arts and Humanities
# 479                    NaN  Science & Engineering & Applied Science
# 369                    NaN                                     None
#
#                                      course_identifier  \
# 273  EMR 1010 Topics in Latinx Studies: Latinx Lite...
# 723            ARABIC 131A Upper-Level Modern Arabic l
# 851  ITAL 40 Advanced Italian I: Italian Through Ci...
# 479  HEB 123 Dogs: Behavior, evolution, and domesti...
# 369  FYSEMR 52Z Attention Deficit Hyperactivity Dis...
#
#                                 best_gem_comment_short  \
# 273            Absolutely take this class – total gem!
# 723        Ustaadha Aya is a Harvard gem of a teacher!
# 851  Chiara is a gem, but can be kind of a tough gr...
# 479                       TAKE THIS CLASS, a true gem.
# 369  It's a gem for sure, the debates are engaging,...
#
#                                     best_comment_short  \
# 273  It's a very enlightening and super fun course ...
# 723  Every day she shows up with a huge amount of e...
# 851  It was also so wonderful to take a course with...
# 479  Really cool to be exposed to lab work with liv...
# 369  Really great and passionate professor :) Made ...
#
#                                     best_comment_first
# 273                           PLEASE TAKE THIS COURSE!
# 723  I would strongly, STRONGLY recommend continuin...
# 851                                  TAKE THIS CLASS!!
# 479            This class is such a great opportunity.
# 369                                   TAKE this class.

# %%
# filter by work hours <= 4
df_super_gem[df_super_gem['workload_score_mean']<4].head()
# Out:
#     course_code                                  course_title_2024  \
# 273    EMR 1010  Topics in Latinx Studies: Introduction to Lati...
# 369  FYSEMR 52Z  Attention Deficit Hyperactivity Disorder (ADHD...
# 809    PSY 1813                   Technology and Mental Health 001
# 947    SCRB 145  From Cells to Tissues, in Sickness and in Heal...
# 749     OEB 104               The Mouse in Science and Society 001
#
#         course_teacher                                               link  \
# 273        Bouso Gavin  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 369             Arnett  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 809              Singh  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 947                Hsu  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 749  Pritchett-Corning  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                                 unique_code  \
# 273  FAS-218600-2248-1-1-001        FAS-218600-2248-1-1-001(Bouso Gavin)
# 369  FAS-224001-2248-1-1-001             FAS-224001-2248-1-1-001(Arnett)
# 809  FAS-220092-2248-1-1-001              FAS-220092-2248-1-1-001(Singh)
# 947  FAS-161207-2248-1-1-001                FAS-161207-2248-1-1-001(Hsu)
# 749  FAS-161184-2248-1-1-001  FAS-161184-2248-1-1-001(Pritchett-Corning)
#
#     course_id  num_responded  num_students  course_score_mean  \
# 273    218600              5             5               4.80
# 369    224001             13            13               4.38
# 809    220092             35            40               4.74
# 947    161207             21            26               4.84
# 749    161184             20            24               5.00
#
#      course_score_median  course_score_mode  course_score_stdev  \
# 273                  5.0                5.0            0.402015
# 369                  5.0                5.0            0.737111
# 809                  5.0                5.0            0.609272
# 947                  5.0                5.0            0.368453
# 749                  5.0                5.0            0.000000
#
#      lecturer_score_mean  lecturer_score_median  lecturer_score_mode  \
# 273                 4.75                    5.0                  5.0
# 369                 4.69                    5.0                  5.0
# 809                 4.87                    5.0                  5.0
# 947                 4.94                    5.0                  5.0
# 749                 5.00                    5.0                  5.0
#
#      lecturer_score_stdev  workload_score_mean  workload_score_median  \
# 273              0.435194                 3.20                    3.0
# 369              0.614554                 3.42                    2.0
# 809              0.512865                 3.40                    3.0
# 947              0.238683                 3.63                    3.0
# 749              0.000000                 3.53                    2.0
#
#      workload_score_mode  workload_score_stdev  rec_score_mean  \
# 273                  3.0                  1.10            4.75
# 369                  1.0                  4.08            4.69
# 809                  2.0                  2.25            4.77
# 947                  3.0                  1.30            4.95
# 749                  2.0                  3.66            5.00
#
#      rec_score_median  rec_score_mode  rec_score_stdev  sentiment_score_mean  \
# 273               5.0             5.0             0.50              0.687100
# 369               5.0             5.0             0.48              0.867075
# 809               5.0             5.0             0.62              0.822832
# 947               5.0             5.0             0.23              0.939285
# 749               5.0             5.0             0.00              0.871813
#
#      sentiment_score_median  sentiment_score_mode  sentiment_score_stdev  \
# 273                 0.65880                0.9621               0.261999
# 369                 0.90905                0.9640               0.133793
# 809                 0.91980                0.9643               0.226523
# 947                 0.96070                0.9041               0.050517
# 749                 0.91670                0.6249               0.144020
#
#      gem_probability_mean  gem_probability_median  gem_probability_mode  \
# 273              0.333333                     0.0                   0.0
# 369              0.125000                     0.0                   0.0
# 809              0.105263                     0.0                   0.0
# 947              0.076923                     0.0                   0.0
# 749              0.066667                     0.0                   0.0
#
#      gem_probability_stdev                                       best_comment  \
# 273               0.577350  PLEASE TAKE THIS COURSE! You absolutely will n...
# 369               0.353553  TAKE this class. This is the best class! Reall...
# 809               0.315302  take. this. class. Super easy and fun, and lea...
# 947               0.277350  Loved this class! Super organized and manageab...
# 749               0.258199  Take this class!! I’d been waiting to get in t...
#
#      max_sent_score worse_comment  min_sent_score  \
# 273          0.9621           NaN             0.0
# 369          0.9640           NaN             0.0
# 809          0.9643           NaN             0.0
# 947          0.9885           NaN             0.0
# 749          0.9894           NaN             0.0
#
#                                       best_gem_comment  max_gem_probability  \
# 273  Absolutely take this class – total gem! You wi...               0.6588
# 369  TAKE THIS COURSE!!! If you have any interest i...               0.9619
# 809  This is actually an amazing class! Definitely ...               0.9614
# 947  SCRB 145 has been my favorite SCRB course I've...               0.9850
# 749  take this class. great way to learn. great mat...               0.9773
#
#                                      course_title_2025 subject_catalog  \
# 273  Topics in Latinx Studies: Latinx Literature an...        EMR 1010
# 369  Attention Deficit Hyperactivity Disorder (ADHD...    FYSEMR   52Z
# 809                       Technology and Mental Health        PSY 1813
# 947   From Cells to Tissues, in Sickness and in Health       SCRB  145
# 749                   The Mouse in Science and Society        OEB  104
#
#                     instructors  year_term  term_type  start_date    end_date  \
# 273           Aitor Bouso Gavin  2025 Fall  Full Term  2025-09-02  2025-12-03
# 369                 Anne Arnett  2025 Fall  Full Term  2025-09-02  2025-12-03
# 809               Shifali Singh  2025 Fall  Full Term  2025-09-02  2025-12-03
# 947                Ya-chieh Hsu  2025 Fall  Full Term  2025-09-02  2025-12-03
# 749  Kathleen Pritchett-Corning  2025 Fall  Full Term  2025-09-02  2025-12-03
#
#     start_time end_time weekdays  class_number     consent enrolled  waitlist  \
# 273    12:00pm   1:15pm  Tue Thu         13216  No Consent        0         0
# 369     3:00pm   5:00pm      Wed         15412  Instructor     0/15         0
# 809     3:00pm   5:00pm      Thu         13886  No Consent        0         0
# 947    10:30am  11:45am  Tue Thu         13767  Instructor     0/28         0
# 749     9:00am  10:15am  Tue Thu         13497  Instructor     0/18         0
#
#      lecture_sunday  lecture_monday  lecture_tuesday  lecture_wednesday  \
# 273           False           False             True              False
# 369           False           False            False               True
# 809           False           False            False              False
# 947           False           False             True              False
# 749           False           False             True              False
#
#      lecture_thursday  lecture_friday  lecture_saturday  \
# 273              True           False             False
# 369             False           False             False
# 809              True           False             False
# 947              True           False             False
# 749              True           False             False
#
#                                            description notes  \
# 273  This is a broad-based course that utilizes art...   NaN
# 369  This first-year seminar will dive into the sci...   NaN
# 809  How does screen time relate to changes in emot...   NaN
# 947  Every cell is a part of a larger “community”, ...   NaN
# 749  Mice remain the most popular vertebrates used ...   NaN
#
#                          school  units  \
# 273  Faculty of Arts & Sciences      4
# 369  Faculty of Arts & Sciences      4
# 809  Faculty of Arts & Sciences      4
# 947  Faculty of Arts & Sciences      4
# 749  Faculty of Arts & Sciences      4
#
#                            cross_registration                      department  \
# 273  Available for Harvard Cross Registration    Ethnicity, Migration, Rights
# 369      Not Available for Cross Registration      First Year Seminar Program
# 809  Available for Harvard Cross Registration                      Psychology
# 947  Available for Harvard Cross Registration   Stem Cell & Regenerative Biol
# 749  Available for Harvard Cross Registration  Organismic & Evolutionary Biol
#
#     course_component  instruction_mode                    grading_basis  \
# 273          Lecture               NaN                FAS Letter Graded
# 369          Seminar               NaN  FAS Satisfactory/Unsatisfactory
# 809          Lecture               NaN                FAS Letter Graded
# 947          Lecture               NaN                FAS Letter Graded
# 749          Lecture               NaN                FAS Letter Graded
#
#                                    course_requirements general_education  \
# 273                                                NaN               NaN
# 369              Course open to Freshman Students Only               NaN
# 809  SLS20 or PSY1 or Psychology AP=5 or Psychology...               NaN
# 947                                                NaN               NaN
# 749                                                NaN               NaN
#
#     quantitative_reasoning                  divisional_distribution  \
# 273                    NaN                      Arts and Humanities
# 369                    NaN                                     None
# 809                    NaN                          Social Sciences
# 947                    NaN  Science & Engineering & Applied Science
# 749                    NaN  Science & Engineering & Applied Science
#
#                                      course_identifier  \
# 273  EMR 1010 Topics in Latinx Studies: Latinx Lite...
# 369  FYSEMR 52Z Attention Deficit Hyperactivity Dis...
# 809              PSY 1813 Technology and Mental Health
# 947  SCRB 145 From Cells to Tissues, in Sickness an...
# 749           OEB 104 The Mouse in Science and Society
#
#                                 best_gem_comment_short  \
# 273            Absolutely take this class – total gem!
# 369  It's a gem for sure, the debates are engaging,...
# 809                                  Definitely a gem.
# 947  Ya–chieh is an absolute gem of a professor, an...
# 749     Don't cheat yourself by saying oh gem, easy A.
#
#                                     best_comment_short  \
# 273  It's a very enlightening and super fun course ...
# 369  Really great and passionate professor :) Made ...
# 809  Super easy and fun, and learning about how tec...
# 947  Ya–Chieh is amazing, so passionate, and cares ...
# 749  She’s super funny and makes lectures super int...
#
#            best_comment_first
# 273  PLEASE TAKE THIS COURSE!
# 369          TAKE this class.
# 809                     take.
# 947         Loved this class!
# 749         Take this class!!

# %%
# Create folder with dates as name
folder_name = f"{myharvard_year}_{myharvard_term}_{qguide_year}_{qguide_term}"
output_dir = os.path.join(repo_root, "release", "hugems", folder_name)
os.makedirs(output_dir, exist_ok=True)

# Define output path for super gems
output_path = os.path.join(output_dir, "super_gems.json")

# Save the super gems data
df_super_gem[[
    'course_code',
    'course_title_2025',
    'course_score_mean',
    'rec_score_mean',
    'gem_probability_mean',
    'sentiment_score_median',
    'best_gem_comment',
    'workload_score_mean',
    'best_gem_comment_short',
    'course_id',
    'link'
]].to_json(output_path, orient='records')

print(f"Super gems data saved to: {output_path}")
# Out:
# Super gems data saved to: /Users/jeqcho/harvard_gem_finder/release/hugems/2025_Fall_2024_Fall/super_gems.json

# %%
department_list = [x for x in df['department'].unique() if str(x)!='nan']
department_list.sort()
import json
output_path = os.path.join(repo_root, "release", "hugems", folder_name, "department_list.json")
with open(output_path, "w") as f:
    json.dump(department_list, f)
department_list
# Out:
# ['African & African Amer Studies',
#  'Anthropology',
#  'Applied Computation',
#  'Applied Mathematics',
#  'Applied Physics',
#  'Art, Film, and Visual Studies',
#  'Astronomy',
#  'Bio Sciences in Public Health',
#  'Biomedical Engineering',
#  'Biostatistics',
#  'Chemistry & Chemical Biology',
#  'Classics, The',
#  'Comparative Literature',
#  'Computer Science',
#  'Earth & Planetary Sciences',
#  'East Asian Langs & Civ',
#  'Economics',
#  'Education Studies',
#  'Engineering Sciences',
#  'English',
#  'Envi Science & Public Policy',
#  'Environmental Sci & Engineer',
#  'Ethnicity, Migration, Rights',
#  'Expository Writing',
#  'First Year Seminar Program',
#  'Folklore & Mythology',
#  'General Education',
#  'Germanic Languages & Lit',
#  'Global Health & Health Policy',
#  'Government',
#  'Health Policy',
#  'History',
#  'History & Literature',
#  'History of Art & Architecture',
#  'History of Science',
#  'Human Evolutionary Biology',
#  'Humanities',
#  'Linguistics',
#  'Mathematics',
#  'Medical Sciences',
#  'Mind, Brain & Behavior',
#  'Molecular & Cellular Biology',
#  'Music',
#  'Near Eastern Languages & Civ',
#  'Neuroscience',
#  'Organismic & Evolutionary Biol',
#  'Philosophy',
#  'Physics',
#  'Psychology',
#  'Quantum Science & Engineering',
#  'Regional Studies-East Asia',
#  'Religion, The Study of',
#  'Romance Languages & Lit',
#  'Russia, E Europe, Central Asia',
#  'Slavic Languages & Literatures',
#  'Social Studies',
#  'Sociology',
#  'South Asian Studies',
#  'Statistics',
#  'Stem Cell & Regenerative Biol',
#  'The Lemann Prog on Creativity',
#  'Theater, Dance & Media',
#  'Women, Gender & Sexuality']

# %%
def get_gems_of_department(department):
  df_gem_of_department = df[
     (df['department'] == department)
  & (df['gem_probability_mean'] > 0)
  & (df['num_responded']/df['num_students'] >= 0.8-0.1*numpy.log2(df['num_students']/10))
  & (df['workload_score_mean'] < 7)
  & (df['course_id'] != '-1')
  ]

  df_gem_of_department = df_gem_of_department.sort_values(by=['gem_probability_mean'],ascending=False).head(5)
  
  # Create departments directory if it doesn't exist
  departments_dir = os.path.join(repo_root, "release", "hugems", folder_name, "departments")
  os.makedirs(departments_dir, exist_ok=True)
  
  df_gem_of_department[[
    'course_code',
    f'course_title_{myharvard_year}',
    'course_score_mean',
    'rec_score_mean',
    'gem_probability_mean',
    'sentiment_score_median',
    'best_gem_comment',
    'workload_score_mean',
    'best_gem_comment_short',
    'course_id',
    'link'
  ]].to_json(os.path.join(departments_dir, department+'.json'), orient='records')

# %%
for department in department_list:
  get_gems_of_department(department)

# %%
df[df['department'] == 'Expository Writing']
# Out:
#     course_code                       course_title_2024 course_teacher  \
# 275    EXPOS 10  Introduction to Expository Writing 101       Bellanca
# 301    EXPOS 20               Expository Writing 20 203           Baca
# 346    EXPOS 40           Public Speaking Practicum 003    Coburn-Palo
#
#                                                   link  \
# 275  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 301  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 346  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                           unique_code course_id  \
# 275  FAS-118262-2248-1-1-101     FAS-118262-2248-1-1-101(Bellanca)    118262
# 301  FAS-116353-2248-1-1-203         FAS-116353-2248-1-1-203(Baca)    116353
# 346  FAS-125227-2248-1-1-003  FAS-125227-2248-1-1-003(Coburn-Palo)    125227
#
#      num_responded  num_students  course_score_mean  course_score_median  \
# 275              7             8               5.00                  5.0
# 301             14            15               4.57                  5.0
# 346             14            15               5.00                  5.0
#
#      course_score_mode  course_score_stdev  lecturer_score_mean  \
# 275                5.0            0.000000                 5.00
# 301                5.0            0.623691                 5.00
# 346                5.0            0.000000                 4.92
#
#      lecturer_score_median  lecturer_score_mode  lecturer_score_stdev  \
# 275                    5.0                  5.0               0.00000
# 301                    5.0                  5.0               0.00000
# 346                    5.0                  5.0               0.27266
#
#      workload_score_mean  workload_score_median  workload_score_mode  \
# 275                 4.33                    4.0                  4.0
# 301                 4.50                    4.0                  4.0
# 346                 4.17                    3.0                  2.0
#
#      workload_score_stdev  rec_score_mean  rec_score_median  rec_score_mode  \
# 275                  1.51            4.29               4.0             4.0
# 301                  1.34            4.54               5.0             5.0
# 346                  3.24            4.92               5.0             5.0
#
#      rec_score_stdev  sentiment_score_mean  sentiment_score_median  \
# 275             0.76               0.41830                 0.46060
# 301             0.66               0.82251                 0.90545
# 346             0.29               0.82288                 0.93710
#
#      sentiment_score_mode  sentiment_score_stdev  gem_probability_mean  \
# 275               -0.1068               0.505280                   0.0
# 301                0.8678               0.200166                   0.1
# 346                0.9700               0.278772                   0.0
#
#      gem_probability_median  gem_probability_mode  gem_probability_stdev  \
# 275                     0.0                   0.0               0.000000
# 301                     0.0                   0.0               0.316228
# 346                     0.0                   0.0               0.000000
#
#                                           best_comment  max_sent_score  \
# 275  TAKE THIS COURSE WITH PAT!! Studio 10 with Pat...          0.9011
# 301  You should absolutely consider taking this cla...          0.9877
# 346  Nick is the BEST! His expertise is obvious in ...          0.9700
#
#                                          worse_comment  min_sent_score  \
# 275  This course is good for you if you have not a ...         -0.1068
# 301                                                NaN          0.0000
# 346                                                NaN          0.0000
#
#                                       best_gem_comment  max_gem_probability  \
# 275                                                                  0.0000
# 301  This class is truly extraordinary and an expos...               0.9311
# 346                                                                  0.0000
#
#                       course_title_2025 subject_catalog        instructors  \
# 275  Introduction to Expository Writing  EXPOS   10 101  Patricia Bellanca
# 301               Expository Writing 20  EXPOS   20 201       Sheza Alqera
# 346           Public Speaking Practicum  EXPOS   40 001       Erika Bailey
#
#      year_term  term_type  start_date    end_date start_time end_time  \
# 275  2025 Fall  Full Term  2025-09-02  2025-12-03     3:00pm   4:15pm
# 301  2025 Fall  Full Term  2025-09-02  2025-12-03    10:30am  11:45am
# 346  2025 Fall  Full Term  2025-09-02  2025-12-03    12:45pm   2:45pm
#
#     weekdays  class_number     consent enrolled  waitlist  lecture_sunday  \
# 275  Mon Wed         14324  Department     0/10         0           False
# 301  Tue Thu         13031  Department     0/15         0           False
# 346  Tue Thu         12935  Instructor     0/15         0           False
#
#      lecture_monday  lecture_tuesday  lecture_wednesday  lecture_thursday  \
# 275            True            False               True             False
# 301           False             True              False              True
# 346           False             True              False              True
#
#      lecture_friday  lecture_saturday  \
# 275           False             False
# 301           False             False
# 346           False             False
#
#                                            description  \
# 275  In Expos Studio 10, students practice analyzin...
# 301  An intensive seminar that aims to improve each...
# 346  Expos 40 is an elective within the Writing Pro...
#
#                                                  notes  \
# 275  After taking Expos Studio 10, a student must p...
# 301  Students must pass one term of Expository Writ...
# 346                                                NaN
#
#                          school  units                    cross_registration  \
# 275  Faculty of Arts & Sciences      4  Not Available for Cross Registration
# 301  Faculty of Arts & Sciences      4  Not Available for Cross Registration
# 346  Faculty of Arts & Sciences      4  Not Available for Cross Registration
#
#              department course_component  instruction_mode      grading_basis  \
# 275  Expository Writing          Seminar               NaN  FAS Letter Graded
# 301  Expository Writing          Seminar               NaN  FAS Letter Graded
# 346  Expository Writing          Lecture               NaN  FAS Letter Graded
#
#     course_requirements general_education quantitative_reasoning  \
# 275                 NaN               NaN                    NaN
# 301                 NaN               NaN                    NaN
# 346                 NaN               NaN                    NaN
#
#     divisional_distribution                            course_identifier  \
# 275                    None  EXPOS 10 Introduction to Expository Writing
# 301                    None               EXPOS 20 Expository Writing 20
# 346                    None           EXPOS 40 Public Speaking Practicum
#
#                                 best_gem_comment_short  \
# 275
# 301  This class is truly extraordinary and an expos...
# 346
#
#                                     best_comment_short  \
# 275  She’s so thoughtful, articulate, and flexible–...
# 301  The most prominent strength of this course was...
# 346                                  Nick is the BEST!
#
#                                     best_comment_first
# 275                        TAKE THIS COURSE WITH PAT!!
# 301  You should absolutely consider taking this class.
# 346                                  Nick is the BEST!

# %%
print(len(df[df['course_id']!='-1']))
# Out:
# 515

# %%
print(len(df[
    (df['course_id']!='-1')
    &(df['gem_probability_mean']>0)
]))
# Out:
# 36

# %%
df_great_courses = df[(df['course_score_median'] == 5)
& (df['lecturer_score_median'] == 5)
& (df['rec_score_median'] == 5)
& (df['gem_probability_mean'] <= 0)
& (df['num_responded']/df['num_students'] >= 0.8-0.1*numpy.log2(df['num_students']/10))
& (df['course_id'] != '-1')
& (df['workload_score_mean'] > 4)
]

print(len(df_great_courses))
df_great_courses = df_great_courses.sort_values(by=['course_score_mean'],ascending=False)

# Create departments directory if it doesn't exist
  
df_great_courses[[
    'course_code',
    f'course_title_{myharvard_year}',
    'course_score_mean',
    'rec_score_mean',
    'gem_probability_mean',
    'sentiment_score_median',
    'best_gem_comment',
    'workload_score_mean',
    'best_gem_comment_short',
    'best_comment',
    'best_comment_short',
    'best_comment_first',
    'course_id',
    'link'
  ]].to_json(os.path.join(repo_root, "release", "hugems", folder_name,'great_courses.json'), orient='records')
df_great_courses.head()
# Out:
# 129
#       course_code                                  course_title_2024  \
# 0    AFRAMER 133Y  The Politics of Paradise: Tourism in Latin Ame...
# 897      RUSS AAB                 Elementary Russian (Intensive) 001
# 364    FYSEMR 41K                  Human Rights, Law and Advocacy 01
# 428      GOV 1796  Central Challenges of American National Securi...
# 459       HAA 99A                         Tutorial - Senior Year 001
#
#      course_teacher                                               link  \
# 0             Henry  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 897    Pastushenkov  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 364       Farbstein  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 428         Allison  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 459  Lambert-Beatty  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                     fas_code                              unique_code  \
# 0    FAS-224623-2248-1-1-001           FAS-224623-2248-1-1-001(Henry)
# 897  FAS-113925-2248-1-1-001    FAS-113925-2248-1-1-001(Pastushenkov)
# 364   FAS-121017-2248-1-1-01        FAS-121017-2248-1-1-01(Farbstein)
# 428  FAS-113210-2248-1-1-001         FAS-113210-2248-1-1-001(Allison)
# 459  FAS-112484-2248-1-1-001  FAS-112484-2248-1-1-001(Lambert-Beatty)
#
#     course_id  num_responded  num_students  course_score_mean  \
# 0      224623              7             7                5.0
# 897    113925              5             5                5.0
# 364    121017             13            14                5.0
# 428    113210              9             9                5.0
# 459    112484              6             7                5.0
#
#      course_score_median  course_score_mode  course_score_stdev  \
# 0                    5.0                5.0                 0.0
# 897                  5.0                5.0                 0.0
# 364                  5.0                5.0                 0.0
# 428                  5.0                5.0                 0.0
# 459                  5.0                5.0                 0.0
#
#      lecturer_score_mean  lecturer_score_median  lecturer_score_mode  \
# 0                   5.00                    5.0                  5.0
# 897                 5.00                    5.0                  5.0
# 364                 5.00                    5.0                  5.0
# 428                 4.83                    5.0                  5.0
# 459                 5.00                    5.0                  5.0
#
#      lecturer_score_stdev  workload_score_mean  workload_score_median  \
# 0                0.000000                 4.43                    4.0
# 897              0.000000                10.80                   10.0
# 364              0.000000                 4.67                    4.0
# 428              0.377525                11.50                   11.0
# 459              0.000000                 6.60                    6.0
#
#      workload_score_mode  workload_score_stdev  rec_score_mean  \
# 0                    4.0                  1.72            5.00
# 897                 10.0                  2.28            4.40
# 364                  4.0                  2.50            4.92
# 428                 17.0                  3.94            5.00
# 459                  8.0                  1.34            5.00
#
#      rec_score_median  rec_score_mode  rec_score_stdev  sentiment_score_mean  \
# 0                 5.0             5.0             0.00              0.911167
# 897               5.0             5.0             0.89              0.932275
# 364               5.0             5.0             0.28              0.777325
# 428               5.0             5.0             0.00              0.687850
# 459               5.0             5.0             0.00              0.630250
#
#      sentiment_score_median  sentiment_score_mode  sentiment_score_stdev  \
# 0                   0.92860                0.9748               0.065004
# 897                 0.96695                0.7957               0.095434
# 364                 0.94135                0.9359               0.338279
# 428                 0.68785                0.4111               0.391384
# 459                 0.63025                0.7867               0.221254
#
#      gem_probability_mean  gem_probability_median  gem_probability_mode  \
# 0                     0.0                     0.0                   0.0
# 897                   0.0                     0.0                   0.0
# 364                   0.0                     0.0                   0.0
# 428                   0.0                     0.0                   0.0
# 459                   0.0                     0.0                   0.0
#
#      gem_probability_stdev                                       best_comment  \
# 0                      0.0  TAKE THIS CLASS! The best course I have taken ...
# 897                    0.0  TLDR: Take this class – my favorite class of a...
# 364                    0.0  TAKE THIS CLASS!!! I'm fully a STEM major but ...
# 428                    0.0  This class is the best that I've taken at Harv...
# 459                    0.0  don't be scared by the rate of assignments. th...
#
#      max_sent_score worse_comment  min_sent_score best_gem_comment  \
# 0            0.9748           NaN             0.0
# 897          0.9995           NaN             0.0
# 364          0.9881           NaN             0.0
# 428          0.9646           NaN             0.0
# 459          0.7867           NaN             0.0
#
#      max_gem_probability                                  course_title_2025  \
# 0                    0.0  The Politics of Paradise: Tourism in Latin Ame...
# 897                  0.0                     Elementary Russian (Intensive)
# 364                  0.0                     Human Rights, Law and Advocacy
# 428                  0.0  Central Challenges of American National Securi...
# 459                  0.0                             Tutorial - Senior Year
#
#     subject_catalog            instructors  year_term  term_type  start_date  \
# 0     AFRAMER  133Y            Amber Henry  2025 Fall  Full Term  2025-09-02
# 897    RUSS     AAB         Jenya Mironava  2025 Fall  Full Term  2025-09-02
# 364    FYSEMR   41K        Susan Farbstein  2025 Fall  Full Term  2025-09-02
# 428        GOV 1796                    NaN  2025 Fall  Full Term  2025-09-02
# 459       HAA   99A  Carrie Lambert-Beatty  2025 Fall  Full Term  2025-09-02
#
#        end_date start_time end_time             weekdays  class_number  \
# 0    2025-12-03    12:00pm   2:45pm                  Tue         15920
# 897  2025-12-03     9:00am  10:00am  Mon Tue Wed Thu Fri         12399
# 364  2025-12-03    12:00pm   2:30pm                  Wed         13966
# 428  2025-12-03        NaN      NaN                  NaN         19650
# 459  2025-12-03     9:00am  11:45am                  Thu         11412
#
#         consent enrolled  waitlist  lecture_sunday  lecture_monday  \
# 0    Instructor     0/30         0           False           False
# 897  No Consent        0         0           False            True
# 364  Instructor     0/14         0           False           False
# 428  Instructor        0         0           False           False
# 459  Instructor        0         0           False           False
#
#      lecture_tuesday  lecture_wednesday  lecture_thursday  lecture_friday  \
# 0               True              False             False           False
# 897             True               True              True            True
# 364            False               True             False           False
# 428            False              False             False           False
# 459            False              False              True           False
#
#      lecture_saturday                                        description  \
# 0               False  What does tourism sell? How do destination ima...
# 897             False  An intensive version of Russian AA: Elementary...
# 364             False  Human rights practitioners confront numerous e...
# 428             False  From the rise of China and resurgence of Russi...
# 459             False  In the fall term, HAA 99 includes several grou...
#
#                                                  notes  \
# 0                                                  NaN
# 897  This course will meet five days a week (Monday...
# 364  This seminar will meet for 2 hours only, Weds,...
# 428                                                NaN
# 459  Required of honors candidates in History of Ar...
#
#                          school  units  \
# 0    Faculty of Arts & Sciences      4
# 897  Faculty of Arts & Sciences      8
# 364  Faculty of Arts & Sciences      4
# 428  Faculty of Arts & Sciences      4
# 459  Faculty of Arts & Sciences      4
#
#                            cross_registration                      department  \
# 0    Available for Harvard Cross Registration  African & African Amer Studies
# 897  Available for Harvard Cross Registration  Slavic Languages & Literatures
# 364      Not Available for Cross Registration      First Year Seminar Program
# 428  Available for Harvard Cross Registration                      Government
# 459      Not Available for Cross Registration   History of Art & Architecture
#
#     course_component  instruction_mode                    grading_basis  \
# 0            Lecture               NaN                FAS Letter Graded
# 897          Lecture               NaN                FAS Letter Graded
# 364          Seminar               NaN  FAS Satisfactory/Unsatisfactory
# 428          Seminar               NaN                FAS Letter Graded
# 459         Tutorial               NaN  FAS Satisfactory/Unsatisfactory
#
#     course_requirements general_education quantitative_reasoning  \
# 0                   NaN               NaN                    NaN
# 897                 NaN               NaN                    NaN
# 364                 NaN               NaN                    NaN
# 428                 NaN               NaN                    NaN
# 459                 NaN               NaN                    NaN
#
#     divisional_distribution  \
# 0           Social Sciences
# 897                    None
# 364                    None
# 428         Social Sciences
# 459     Arts and Humanities
#
#                                      course_identifier best_gem_comment_short  \
# 0    AFRAMER 133Y The Politics of Paradise: Tourism...
# 897            RUSS AAB Elementary Russian (Intensive)
# 364          FYSEMR 41K Human Rights, Law and Advocacy
# 428  GOV 1796 Central Challenges of American Nation...
# 459                     HAA 99A Tutorial - Senior Year
#
#                                     best_comment_short  \
# 0    Politics of Paradise offers an incredibly enga...
# 897  Not sure who the TF will be but they will teac...
# 364  Prof. Farbstein is insanely smart, talented, a...
# 428  There are so many opportunities for engagement...
# 459  more than anything, i think this class is here...
#
#                                     best_comment_first
# 0                                     TAKE THIS CLASS!
# 897  TLDR: Take this class – my favorite class of a...
# 364                                 TAKE THIS CLASS!!!
# 428  This class is the best that I've taken at Harv...
# 459        don't be scared by the rate of assignments.

# %%
df_hidden_gems = df[
    (df["course_score_median"] == 5)
    & (df["lecturer_score_median"] == 5)
    & (df["rec_score_median"] == 5)
    & (df["gem_probability_mean"] <= 0)
    & (
        df["num_responded"] / df["num_students"]
        >= 0.8 - 0.1 * numpy.log2(df["num_students"] / 10)
    )
    & (df["course_id"] != "-1")
    & (df["workload_score_mean"] <= 4)
]

print(len(df_hidden_gems))
df_hidden_gems = df_hidden_gems.sort_values(by=["workload_score_mean"], ascending=True)

df_hidden_gems[
    [
        "course_code",
        f"course_title_{myharvard_year}",
        "course_score_mean",
        "rec_score_mean",
        "gem_probability_mean",
        "sentiment_score_median",
        "best_gem_comment",
        "workload_score_mean",
        "best_gem_comment_short",
        "best_comment",
        "best_comment_short",
        "best_comment_first",
        "course_id",
        "link",
    ]
].to_json(
    os.path.join(repo_root, "release", "hugems", folder_name, "hidden_gems.json"),
    orient="records",
)
df_hidden_gems.head()
# Out:
# 32
#       course_code                                  course_title_2024  \
# 418        GOV 95  Safra Undergraduate Ethics Fellowship Workshop...
# 53      BPH 304QC  Eradicating Malaria and Neglected Tropical Dis...
# 473        HEB 30                        Primate Social Behavior 001
# 71       CHEM 145               Experimental Inorganic Chemistry LAB
# 85   CLS-STDY 166                          Bob Dylan the Classic 001
#
#     course_teacher                                               link  \
# 418       Beerbohm  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 53      Duraisingh  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 473        Surbeck  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 71   Dogutan Kiper  https://harvard.bluera.com/harvard/rpv-eng.asp...
# 85          Thomas  https://harvard.bluera.com/harvard/rpv-eng.asp...
#
#                      fas_code                             unique_code  \
# 418   FAS-223109-2248-1-1-001       FAS-223109-2248-1-1-001(Beerbohm)
# 53   FAS-127601-2248-F2-1-001    FAS-127601-2248-F2-1-001(Duraisingh)
# 473   FAS-113837-2248-1-1-001        FAS-113837-2248-1-1-001(Surbeck)
# 71    FAS-109110-2248-1-1-LAB  FAS-109110-2248-1-1-LAB(Dogutan Kiper)
# 85    FAS-222226-2248-1-1-001         FAS-222226-2248-1-1-001(Thomas)
#
#     course_id  num_responded  num_students  course_score_mean  \
# 418    223109             13            13               4.92
# 53     127601              7             8               4.67
# 473    113837              7             7               5.00
# 71     109110              9            10               4.88
# 85     222226             38            45               5.00
#
#      course_score_median  course_score_mode  course_score_stdev  \
# 418                  5.0                5.0            0.272660
# 53                   5.0                5.0            0.472582
# 473                  5.0                5.0            0.000000
# 71                   5.0                5.0            0.336552
# 85                   5.0                5.0            0.000000
#
#      lecturer_score_mean  lecturer_score_median  lecturer_score_mode  \
# 418                 5.00                    5.0                  5.0
# 53                  4.83                    5.0                  5.0
# 473                 5.00                    5.0                  5.0
# 71                  5.00                    5.0                  5.0
# 85                  4.97                    5.0                  5.0
#
#      lecturer_score_stdev  workload_score_mean  workload_score_median  \
# 418              0.000000                 1.67                    2.0
# 53               0.377525                 2.00                    1.5
# 473              0.000000                 2.00                    1.0
# 71               0.000000                 2.25                    2.0
# 85               0.171447                 2.28                    2.0
#
#      workload_score_mode  workload_score_stdev  rec_score_mean  \
# 418                  2.0                  0.52            4.91
# 53                   1.0                  1.26            4.83
# 473                  1.0                  1.67            4.83
# 71                   2.0                  1.04            4.88
# 85                   2.0                  1.22            4.94
#
#      rec_score_median  rec_score_mode  rec_score_stdev  sentiment_score_mean  \
# 418               5.0             5.0             0.30              0.762167
# 53                5.0             5.0             0.41              0.851050
# 473               5.0             5.0             0.41              0.874350
# 71                5.0             5.0             0.35              0.826500
# 85                5.0             5.0             0.25              0.853526
#
#      sentiment_score_median  sentiment_score_mode  sentiment_score_stdev  \
# 418                 0.86550                0.9011               0.210563
# 53                  0.87595                0.9623               0.134317
# 473                 0.87435                0.9219               0.067246
# 71                  0.91080                0.9108               0.183974
# 85                  0.93490                0.8271               0.189367
#
#      gem_probability_mean  gem_probability_median  gem_probability_mode  \
# 418                   0.0                     0.0                   0.0
# 53                    0.0                     0.0                   0.0
# 473                   0.0                     0.0                   0.0
# 71                    0.0                     0.0                   0.0
# 85                    0.0                     0.0                   0.0
#
#      gem_probability_stdev                                       best_comment  \
# 418                    0.0  This class is an excellent continuation of the...
# 53                     0.0  The teaching team is stellar, and the guest le...
# 473                    0.0  TAKE THIS CLASSSS!!!!!!!!!!!!!!!!! I discovere...
# 71                     0.0  This class is run very well, and the workload ...
# 85                     0.0  This is a wonderful course. I had a pretty hea...
#
#      max_sent_score worse_comment  min_sent_score best_gem_comment  \
# 418          0.9011           NaN             0.0
# 53           0.9623           NaN             0.0
# 473          0.9219           NaN             0.0
# 71           0.9611           NaN             0.0
# 85           0.9882           NaN             0.0
#
#      max_gem_probability                                  course_title_2025  \
# 418                  0.0     Safra Undergraduate Ethics Fellowship Workshop
# 53                   0.0  Eradicating Malaria and Neglected Tropical Dis...
# 473                  0.0              Monkey style: Primate Social Behavior
# 71                   0.0                   Experimental Inorganic Chemistry
# 85                   0.0                              Bob Dylan the Classic
#
#     subject_catalog                                    instructors  year_term  \
# 418        GOV   95                                  Eric Beerbohm  2025 Fall
# 53       BPH  304QC  Jeffrey Dvorin, Manoj Duraisingh, Dyann Wirth  2025 Fall
# 473        HEB   30                                 Martin Surbeck  2025 Fall
# 71        CHEM  145                            Dilek Dogutan Kiper  2025 Fall
# 85    CLS-STDY  166                                 Richard Thomas  2025 Fall
#
#      term_type  start_date    end_date start_time end_time weekdays  \
# 418  Full Term  2025-09-02  2025-12-03    12:00pm   1:15pm      Thu
# 53      Fall 2  2025-10-21  2025-12-03     3:45pm   5:15pm  Tue Thu
# 473  Full Term  2025-09-02  2025-12-03    10:30am  11:45am  Tue Thu
# 71   Full Term  2025-09-02  2025-12-03    12:00pm   5:00pm  Tue Thu
# 85   Full Term  2025-09-02  2025-12-03    10:30am  11:45am  Tue Thu
#
#      class_number     consent enrolled  waitlist  lecture_sunday  \
# 418         16035  Instructor        0         0           False
# 53          12536  Instructor     0/45         0           False
# 473         12978  No Consent        0         0           False
# 71          11408  Instructor     0/15         0           False
# 85          14730  Instructor     0/75         0           False
#
#      lecture_monday  lecture_tuesday  lecture_wednesday  lecture_thursday  \
# 418           False            False              False              True
# 53            False             True              False              True
# 473           False             True              False              True
# 71            False             True              False              True
# 85            False             True              False              True
#
#      lecture_friday  lecture_saturday  \
# 418           False             False
# 53            False             False
# 473           False             False
# 71            False             False
# 85            False             False
#
#                                            description  \
# 418  Students will present thesis research that bea...
# 53   This course is a survey to introduce core conc...
# 473  This course provides an overview of primate so...
# 71   Chemistry 145 is a laboratory course designed ...
# 85   This course examines Bob Dylan the creative ge...
#
#                                                  notes  \
# 418  Limited to and required of undergraduate fello...
# 53                                                 NaN
# 473                                                NaN
# 71   Class meeting times Tuesday & Thursday 12:00 p...
# 85                                                 NaN
#
#                          school  units  \
# 418  Faculty of Arts & Sciences      2
# 53   Faculty of Arts & Sciences      2
# 473  Faculty of Arts & Sciences      4
# 71   Faculty of Arts & Sciences      4
# 85   Faculty of Arts & Sciences      4
#
#                            cross_registration                     department  \
# 418  Available for Harvard Cross Registration                     Government
# 53   Available for Harvard Cross Registration  Bio Sciences in Public Health
# 473  Available for Harvard Cross Registration     Human Evolutionary Biology
# 71   Available for Harvard Cross Registration   Chemistry & Chemical Biology
# 85   Available for Harvard Cross Registration                  Classics, The
#
#          course_component  instruction_mode                    grading_basis  \
# 418              Tutorial               NaN  FAS Satisfactory/Unsatisfactory
# 53   Reading and Research               NaN  FAS Satisfactory/Unsatisfactory
# 473               Lecture               NaN                FAS Letter Graded
# 71             Laboratory               NaN                FAS Letter Graded
# 85                Lecture               NaN                FAS Letter Graded
#
#     course_requirements general_education quantitative_reasoning  \
# 418                 NaN               NaN                    NaN
# 53                  NaN               NaN                    NaN
# 473                 NaN               NaN                    NaN
# 71                  NaN               NaN                    NaN
# 85                  NaN               NaN                    NaN
#
#                      divisional_distribution  \
# 418                                     None
# 53                                      None
# 473  Science & Engineering & Applied Science
# 71   Science & Engineering & Applied Science
# 85                       Arts and Humanities
#
#                                      course_identifier best_gem_comment_short  \
# 418  GOV 95 Safra Undergraduate Ethics Fellowship W...
# 53   BPH 304QC Eradicating Malaria and Neglected Tr...
# 473       HEB 30 Monkey style: Primate Social Behavior
# 71           CHEM 145 Experimental Inorganic Chemistry
# 85                  CLS-STDY 166 Bob Dylan the Classic
#
#                                     best_comment_short  \
# 418  This class is an excellent continuation of the...
# 53   Group discussions were excellent, people had g...
# 473                      Martin and Lucy are the BEST.
# 71   ), and based on what others say about the othe...
# 85   I had a pretty heavy course load this semester...
#
#                                     best_comment_first
# 418  This class is an excellent continuation of the...
# 53   The teaching team is stellar, and the guest le...
# 473                 TAKE THIS CLASSSS!!!!!!!!!!!!!!!!!
# 71   This class is run very well, and the workload ...
# 85                         This is a wonderful course.
